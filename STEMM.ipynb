# %% [markdown]
# <a href="https://colab.research.google.com/github/Aanal2901/STEMM_course_project/blob/main/STEMM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/getalp/mass-dataset.git
# Out:
# Cloning into 'mass-dataset'...
# remote: Enumerating objects: 135457, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 135457 (delta 3), reused 4 (delta 1), pack-reused 135443
# Receiving objects: 100% (135457/135457), 185.78 MiB | 7.84 MiB/s, done.
# Resolving deltas: 100% (2208/2208), done.
# Updating files: 100% (135469/135469), done.

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
# !mkdir Data
# %cd Data
# !mkdir French
# !mkdir English
# Out:
# /content/Data
# Archive:  /content/drive/MyDrive/French.zip
# checkdir:  cannot create extraction directory: Data/French
#            No such file or directory
# Archive:  /content/drive/MyDrive/English.zip
# checkdir:  cannot create extraction directory: Data/English
#            No such file or directory

# %%
# !unzip /content/drive/MyDrive/French.zip -d /content/Data/French
# !unzip /content/drive/MyDrive/English.zip -d /content/Data/English
# Out:
# Archive:  /content/drive/MyDrive/French.zip
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___01_Matthieu____FRNTLSN2DA.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___01_Matthieu______N2FRATLS.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___03_Matthieu____FRNTLSN2DA.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___02_Matthieu____FRNTLSN2DA.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___02_Matthieu______N2FRATLS.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___03_Matthieu______N2FRATLS.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___04_Matthieu____FRNTLSN2DA.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___04_Matthieu______N2FRATLS.mp3
#   inflating: /content/Data/French/French_fra_TLS_NT_Drama/B01___05_Matthieu____FRNTLSN2DA.mp3
# ...

# %%
# !git clone https://github.com/Aanal2901/STEMM_course_project.git
# %cd STEMM/
# Out:
# Cloning into 'STEMM_course_project'...
# remote: Enumerating objects: 1104, done.
# remote: Counting objects: 100% (1104/1104), done.
# remote: Compressing objects: 100% (892/892), done.
# remote: Total 1104 (delta 173), reused 1091 (delta 165), pack-reused 0
# Receiving objects: 100% (1104/1104), 3.51 MiB | 1.82 MiB/s, done.
# Resolving deltas: 100% (173/173), done.

# %%
# %cd /content/STEMM_course_project/
# Out:
# /content/STEMM_course_project

# %%
# !sh clean_massdata.sh "french"
# !sh clean_massdata.sh "english"
# Out:
# 1. clean the source sentences in the corpus

# %%
# %cd STEMM
# Out:
# [Errno 2] No such file or directory: 'STEMM'
# /content/STEMM_course_project

# %%
# !pip install --editable ./
# !python3 setup.py install --user
# !python3 setup.py build_ext --inplace
# !pip install inflect sentencepiece soundfile textgrid pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/STEMM
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 315.5 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-1.0.0a0+e3ae190-0.editable-cp39-cp39-linux_x86_64.whl size=6313 sha256=8a1cab81abbe7965e2cd2180616d14d092824caf2d93c1bffb1fa6924bcac9df
# ...

# %%
TGT_LANG="de"
MUSTC_ROOT="/content/data/mustc/"
# !mkdir -p $MUSTC_ROOT

# %%
# %cd $MUSTC_ROOT
# !tar -xzvf MUSTC_v1.0_en-de.tar.gz

# %%
# !sh train.sh $TGT_LANG
# Out:
# tee: logs/.txt: No such file or directory
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ...

# %%
lang = "en"

# %%
# !python3 preprocess_scripts/clean_mustc.py --lang ${lang}
